# %% [markdown]
# # 05 整列: Sorting

# %% [markdown]
# ## 課題
#
# 上記の`bubble()`に、比較の回数をカウントする機能を追加した関数`bubble_with_count()`を用いよう。要素の数を、10、100、1000と増やし、比較の回数をグラフにプロットして、要素数の増加に伴う比較の回数の増加を観察しなさい。
#
# Let us use the function `bubble_with_count()` that adds a feature to count the number of comparisons. Increase the number of elements to 10, 100, and 1000, and plot the number of comparisons on a graph to observe how the number of comparisons increases with the increase in the number of elements.

# %% [markdown]
# ## 課題
# Pythonでは、文字列も大小を比較できる。文字列のリストに対して、選択ソートを行い、辞書順で文字列が整列されることを確認しなさい。
#
# In Python, strings can also be compared in terms of their size. Perform selection sort on a list of strings and confirm that the strings are sorted in lexicographical order.

# %% [markdown]
# ## 課題
# 挿入ソートでは、前から整列済みの部分列ができていく。挿入ソートを実装し、整列済みの部分列がどのようにできていくかを観察しなさい。
#
# Implement insertion sort and observe how the sorted sublist is formed from the front.
