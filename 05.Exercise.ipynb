# %% [markdown]
# # 05 整列: Sorting

# %%
# 学籍番号: 
# 氏名:

# %% [markdown]
# ## 課題
# 講義で紹介した泡立ち法の実装`bubble()`を参考に、大きい順に整列する`bubble_desc()`関数を作成し、、動作を確認しなさい。
#
# Create a `bubble_desc()` function that sorts in descending order, based on the bubble sort implementation `bubble()` introduced in the lecture, and verify its operation.
